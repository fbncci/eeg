# %%
import json
import glob
import mne
import matplotlib.pyplot as plt
import scipy.io
import pandas as pd
import numpy as np

# %%
filepath = "/wsu/home/groups/eeg/eeg-data/download/eeg*.edf"
edf_files = glob.glob(filepath)
annotations = glob.glob('metadata/annot*.csv')

# %%
def load_dataset(file, annotations):
    print(file)
    raw = mne.io.read_raw_edf(file, preload=True,
                              verbose=0)
    print(str("Number of data records: {}").format(int(raw.n_times)))
    print(str("Seconds of data: {}").format(int(raw.n_times)//256))
    df = raw.to_data_frame()
    df.set_index("time", inplace=True, drop=True)
    
    eeg_id = file.split("eeg")[-1].split(".")[0] # example: eeg_id for eeg1.edf is 1
    print(str("eeg patient number: {}").format(eeg_id))
    
    for i,f in enumerate(annotations):
        annot_df = pd.read_csv(f)
        class_labels = annot_df[eeg_id].dropna()
        #if sampling rate is 256 hz and data is labeled every second, this should fit the labels to the data?
        class_labels = [val for val in class_labels for _ in range(256)]
        labs = class_labels[:len(df)]
        df['label_'+str(i)] = labs
        
    return df

# %%
for i,file in enumerate(sorted(edf_files)):
    print(file)
    df = load_dataset(file, annotations)
    csv_name = file.replace("edf", "csv").replace("download", "csv")
    print(csv_name)
    df.to_csv(csv_name)
# Out:
# /wsu/home/groups/eeg/eeg-data/download/eeg1.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg1.edf
# Number of data records: 1790208
# Seconds of data: 6993
# eeg patient number: 1
# /wsu/home/groups/eeg/eeg-data/csv/eeg1.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg10.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg10.edf
# Number of data records: 1389312
# Seconds of data: 5427
# eeg patient number: 10
# /wsu/home/groups/eeg/eeg-data/csv/eeg10.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg11.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg11.edf
# Number of data records: 1916928
# Seconds of data: 7488
# eeg patient number: 11
# /wsu/home/groups/eeg/eeg-data/csv/eeg11.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg12.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg12.edf
# Number of data records: 1143808
# Seconds of data: 4468
# eeg patient number: 12
# /wsu/home/groups/eeg/eeg-data/csv/eeg12.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg13.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg13.edf
# Number of data records: 3946496
# Seconds of data: 15416
# eeg patient number: 13
# /wsu/home/groups/eeg/eeg-data/csv/eeg13.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg14.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg14.edf
# Number of data records: 953856
# Seconds of data: 3726
# eeg patient number: 14
# /wsu/home/groups/eeg/eeg-data/csv/eeg14.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg15.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg15.edf
# Number of data records: 1765888
# Seconds of data: 6898
# eeg patient number: 15
# /wsu/home/groups/eeg/eeg-data/csv/eeg15.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg16.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg16.edf
# Number of data records: 1520896
# Seconds of data: 5941
# eeg patient number: 16
# /wsu/home/groups/eeg/eeg-data/csv/eeg16.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg17.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg17.edf
# Number of data records: 1406208
# Seconds of data: 5493
# eeg patient number: 17
# /wsu/home/groups/eeg/eeg-data/csv/eeg17.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg18.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg18.edf
# Number of data records: 934656
# Seconds of data: 3651
# eeg patient number: 18
# /wsu/home/groups/eeg/eeg-data/csv/eeg18.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg19.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg19.edf
# Number of data records: 2305536
# Seconds of data: 9006
# eeg patient number: 19
# /wsu/home/groups/eeg/eeg-data/csv/eeg19.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg2.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg2.edf
# Number of data records: 962816
# Seconds of data: 3761
# eeg patient number: 2
# /wsu/home/groups/eeg/eeg-data/csv/eeg2.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg20.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg20.edf
# Number of data records: 1020672
# Seconds of data: 3987
# eeg patient number: 20
# /wsu/home/groups/eeg/eeg-data/csv/eeg20.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg21.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg21.edf
# Number of data records: 1460992
# Seconds of data: 5707
# eeg patient number: 21
# /wsu/home/groups/eeg/eeg-data/csv/eeg21.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg22.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg22.edf
# Number of data records: 984064
# Seconds of data: 3844
# eeg patient number: 22
# /wsu/home/groups/eeg/eeg-data/csv/eeg22.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg23.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg23.edf
# Number of data records: 1134848
# Seconds of data: 4433
# eeg patient number: 23
# /wsu/home/groups/eeg/eeg-data/csv/eeg23.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg24.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg24.edf
# Number of data records: 948736
# Seconds of data: 3706
# eeg patient number: 24
# /wsu/home/groups/eeg/eeg-data/csv/eeg24.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg25.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg25.edf
# Number of data records: 1717504
# Seconds of data: 6709
# eeg patient number: 25
# /wsu/home/groups/eeg/eeg-data/csv/eeg25.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg26.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg26.edf
# Number of data records: 1070592
# Seconds of data: 4182
# eeg patient number: 26
# /wsu/home/groups/eeg/eeg-data/csv/eeg26.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg27.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg27.edf
# Number of data records: 894976
# Seconds of data: 3496
# eeg patient number: 27
# /wsu/home/groups/eeg/eeg-data/csv/eeg27.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg28.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg28.edf
# Number of data records: 1473792
# Seconds of data: 5757
# eeg patient number: 28
# /wsu/home/groups/eeg/eeg-data/csv/eeg28.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg29.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg29.edf
# Number of data records: 2057472
# Seconds of data: 8037
# eeg patient number: 29
# /wsu/home/groups/eeg/eeg-data/csv/eeg29.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg3.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg3.edf
# Number of data records: 1129472
# Seconds of data: 4412
# eeg patient number: 3
# /wsu/home/groups/eeg/eeg-data/csv/eeg3.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg30.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg30.edf
# Number of data records: 1007872
# Seconds of data: 3937
# eeg patient number: 30
# /wsu/home/groups/eeg/eeg-data/csv/eeg30.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg31.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg31.edf
# Number of data records: 903424
# Seconds of data: 3529
# eeg patient number: 31
# /wsu/home/groups/eeg/eeg-data/csv/eeg31.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg32.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg32.edf
# Number of data records: 1180928
# Seconds of data: 4613
# eeg patient number: 32
# /wsu/home/groups/eeg/eeg-data/csv/eeg32.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg33.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg33.edf
# Number of data records: 959232
# Seconds of data: 3747
# eeg patient number: 33
# /wsu/home/groups/eeg/eeg-data/csv/eeg33.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg34.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg34.edf
# Number of data records: 1661696
# Seconds of data: 6491
# eeg patient number: 34
# /wsu/home/groups/eeg/eeg-data/csv/eeg34.csv
# /wsu/home/groups/eeg/eeg-data/download/eeg35.edf
# /wsu/home/groups/eeg/eeg-data/download/eeg35.edf
# Number of data records: 964352
# Seconds of data: 3767
# eeg patient number: 35
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-0abbafd8b3bf> in <module>
#       1 for i,file in enumerate(sorted(edf_files)):
#       2     print(file)
# ----> 3     df = load_dataset(file, annotations)
#       4     csv_name = file.replace("edf", "csv").replace("download", "csv")
#       5     print(csv_name)
#
# <ipython-input-21-dd366aeb7d00> in load_dataset(file, annotations)
#      12
#      13     for i,f in enumerate(annotations):
# ---> 14         annot_df = pd.read_csv(f)
#      15         class_labels = annot_df[eeg_id].dropna()
#      16         #if sampling rate is 256 hz and data is labeled every second, this should fit the labels to the data?
#
# /wsu/el7/pre-compiled/python/3.7/envs/pyspark/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /wsu/el7/pre-compiled/python/3.7/envs/pyspark/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /wsu/el7/pre-compiled/python/3.7/envs/pyspark/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /wsu/el7/pre-compiled/python/3.7/envs/pyspark/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /wsu/el7/pre-compiled/python/3.7/envs/pyspark/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File metadata/annotations_2017_B.csv does not exist: 'metadata/annotations_2017_B.csv'
